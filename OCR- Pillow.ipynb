# %%
import numpy as np

# %% [markdown]
# # Pillow library

# %%
from PIL import Image

# %%
# Open the image
im_file = "page_01.jpg"

# %%
# Load the image to memory
im = Image.open(im_file)

print(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x1522 at 0x2B4DABD7790>

# %%
im.size
# Out:
# (1200, 1522)

# %%
# This command will display the image, but not working in this place
im.show()

# %%
# Library to display the image
from IPython.display import display

display(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x1522>

# %%
# Save the file
im.save("Save_im.jpg")
